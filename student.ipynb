# %%
import pandas as pd

# %%
df = pd.read_csv("dataset/student_performance.csv")

# %%
df.head()
# Out:
#                Name  Age  Gender Major Living_Area Parent_Education  \
# 0     Linda Johnson   24  Female  Arts       Rural         Bachelor
# 1     Thomas Thomas   21    Male  Arts    Suburban           Master
# 2  Joseph Rodriguez   23    Male  STEM    Suburban      High School
# 3    Michael Wright   25    Male  STEM       Rural      High School
# 4   Jennifer Nguyen   25  Female  Arts       Urban         Bachelor
#
#   Scholarship_Status Part_Time_Job Extracurricular_Activities Internet_Access  \
# 0                 No            No                         No             Yes
# 1                 No            No                         No             Yes
# 2                Yes            No                         No             Yes
# 3                 No            No                         No             Yes
# 4                Yes            No                         No             Yes
#
#    ...  Sleep_Hours_Per_Day  Attendance_Rate  Stress_Level  Exam_Proximity  \
# ...

# %%
df.shape
# Out:
# (1000, 21)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 21 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Name                        1000 non-null   object
#  1   Age                         1000 non-null   int64
#  2   Gender                      1000 non-null   object
#  3   Major                       1000 non-null   object
#  4   Living_Area                 1000 non-null   object
#  5   Parent_Education            1000 non-null   object
#  6   Scholarship_Status          1000 non-null   object
#  7   Part_Time_Job               1000 non-null   object
#  8   Extracurricular_Activities  1000 non-null   object
#  9   Internet_Access             1000 non-null   object
#  10  Study_Hours_Per_Day         1000 non-null   float64
#  11  Sleep_Hours_Per_Day         1000 non-null   float64
#  12  Attendance_Rate             1000 non-null   float64
# ...

# %%
df.isnull().sum().sort_values(ascending=False)
# Out:
# Name                          0
# Age                           0
# Gender                        0
# Major                         0
# Living_Area                   0
# Parent_Education              0
# Scholarship_Status            0
# Part_Time_Job                 0
# Extracurricular_Activities    0
# Internet_Access               0
# Study_Hours_Per_Day           0
# Sleep_Hours_Per_Day           0
# Attendance_Rate               0
# Stress_Level                  0
# Exam_Proximity                0
# Math_Score                    0
# Science_Score                 0
# Language_Score                0
# History_Score                 0
# Average_Score                 0
# Grade                         0
# dtype: int64

# %%
df.describe()
# Out:
#                Age  Study_Hours_Per_Day  Sleep_Hours_Per_Day  Attendance_Rate  \
# count  1000.000000          1000.000000          1000.000000      1000.000000
# mean     21.453000             4.286350             7.048220        78.418000
# std       2.293698             2.621616             1.242238        13.599243
# min      18.000000             0.500000             2.500000        40.000000
# 25%      19.000000             2.387500             6.210000        69.275000
# 50%      21.000000             3.805000             7.080000        80.950000
# 75%      23.000000             5.815000             7.900000        89.100000
# max      25.000000            15.500000            11.000000        99.800000
#
#        Stress_Level  Math_Score  Science_Score  Language_Score  History_Score  \
# count   1000.000000   1000.0000    1000.000000     1000.000000    1000.000000
# mean       4.060500     70.8390      69.789000       72.719000      69.482000
# ...

# %%
df.corr(numeric_only=True)
# Out:
#                           Age  Study_Hours_Per_Day  Sleep_Hours_Per_Day  \
# Age                  1.000000            -0.003618            -0.027369
# Study_Hours_Per_Day -0.003618             1.000000             0.009925
# Sleep_Hours_Per_Day -0.027369             0.009925             1.000000
# Attendance_Rate      0.003560             0.022644            -0.017410
# Stress_Level        -0.016789            -0.347027            -0.257367
# Math_Score          -0.024674             0.545413             0.214460
# Science_Score        0.005087             0.566731             0.239431
# Language_Score      -0.020089             0.620730             0.215836
# History_Score       -0.054661             0.581293             0.211376
# Average_Score       -0.029380             0.704072             0.268270
#
#                      Attendance_Rate  Stress_Level  Math_Score  Science_Score  \
# Age                         0.003560     -0.016789   -0.024674       0.005087
# ...

# %%
import seaborn as sns
sns.histplot(df['Average_Score'], kde=True)
# Out:
# <Axes: xlabel='Average_Score', ylabel='Count'>

# %%
sns.scatterplot(x='Study_Hours_Per_Day', y='Average_Score',data=df)
# Out:
# <Axes: xlabel='Study_Hours_Per_Day', ylabel='Average_Score'>

# %%
sns.boxplot(x='Sleep_Hours_Per_Day', y='Average_Score', data=df)
# Out:
# <Axes: xlabel='Sleep_Hours_Per_Day', ylabel='Average_Score'>

# %%
sns.boxplot(x='Stress_Level', y='Average_Score', data=df)
# Out:
# <Axes: xlabel='Stress_Level', ylabel='Average_Score'>

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap='coolwarm')
plt.show()

# %%
df = df.drop("Name", axis=1)

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Major', 'Living_Area', 'Parent_Education',
#        'Scholarship_Status', 'Part_Time_Job', 'Extracurricular_Activities',
#        'Internet_Access', 'Study_Hours_Per_Day', 'Sleep_Hours_Per_Day',
#        'Attendance_Rate', 'Stress_Level', 'Exam_Proximity', 'Math_Score',
#        'Science_Score', 'Language_Score', 'History_Score', 'Average_Score',
#        'Grade'],
#       dtype='object')

# %%
x = df.drop("Average_Score", axis=1)
y = df["Average_Score"]

# %%
x = pd.get_dummies(x, drop_first=True)

# %%
'''
selected_features = [
    "Science_Score",
    "Math_Score",
    "Language_Score",
    "Grade_B",
    "History_Score",
    "Grade_C"
]

x_selected = x[selected_features]
'''

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor

model = RandomForestRegressor()
model.fit(x_train,y_train)
y_pred =model.predict(x_test)

# %%
from sklearn.metrics import mean_absolute_error, r2_score

print("MAE:", mean_absolute_error(y_test,y_pred))
print("R2:", r2_score(y_test,y_pred))
# Out:
# MAE: 1.2072000000000003
# R2: 0.9777469663899789

# %%
import pandas as pd

importance = pd.DataFrame({
    "Feature": x.columns,
    "Importance": model.feature_importances_
})

importance.sort_values(
    by="Importance",
    ascending=False
).head(10)
# Out:
#                 Feature  Importance
# 6         Science_Score    0.204733
# 5            Math_Score    0.186262
# 7        Language_Score    0.170639
# 23              Grade_B    0.152808
# 8         History_Score    0.129226
# 24              Grade_C    0.124052
# 25              Grade_D    0.010831
# 1   Study_Hours_Per_Day    0.005192
# 2   Sleep_Hours_Per_Day    0.004635
# 4          Stress_Level    0.003623

# %%
import pandas as pd
import matplotlib.pyplot as plt

importance = pd.DataFrame({
    "Feature": x.columns,
    "Importance": model.feature_importances_
})

importance = importance.sort_values(
    by="Importance",
    ascending=False
)

importance.head(10).plot(
    x="Feature",
    y="Importance",
    kind="bar"
)

plt.show()

# %% [markdown]
# lets move on nlp
